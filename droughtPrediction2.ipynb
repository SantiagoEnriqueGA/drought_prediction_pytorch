# %% [markdown]
# # Drought Prediction

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.decomposition import PCA, KernelPCA
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import cohen_kappa_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import pickle

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Reading the input data

# %%
drought_df_train = pd.read_csv('data/train_timeseries.csv')
drought_df_test = pd.read_csv('data/test_timeseries.csv')
drought_df_test = pd.read_csv('data/validation_timeseries.csv')

drought_df = pd.concat([drought_df_train, drought_df_test, drought_df_test], axis=0)
drought_df.head()
# Out:
#    fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2000-01-01     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 1  1001  2000-01-02     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2  1001  2000-01-03     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 3  1001  2000-01-04    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 4  1001  2000-01-05     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    11.46  ...  14.65   2.20       2.94       1.49         1.46   4.85
# 1    12.61  ...  16.60   2.52       3.43       1.83         1.60   5.33
# 2    15.32  ...  18.41   4.03       5.33       2.66         2.67   7.53
# 3     2.16  ...  11.31   3.84       5.67       2.08         3.59   6.73
# 4    -2.66  ...   2.65   1.60       2.50       0.52         1.98   2.94
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       6.04       3.23         2.81    NaN
# 1       6.13       3.72         2.41    NaN
# 2       9.52       5.87         3.66    NaN
# 3       9.31       3.74         5.58    1.0
# 4       4.85       0.65         4.19    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Initial exploration

# %%
drought_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23838360 entries, 0 to 2268839
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 3.9+ GB

# %%
drought_df.isnull().sum()
# Out:
# fips                  0
# date                  0
# PRECTOT               0
# PS                    0
# QV2M                  0
# T2M                   0
# T2MDEW                0
# T2MWET                0
# T2M_MAX               0
# T2M_MIN               0
# T2M_RANGE             0
# TS                    0
# WS10M                 0
# WS10M_MAX             0
# WS10M_MIN             0
# WS10M_RANGE           0
# WS50M                 0
# WS50M_MAX             0
# WS50M_MIN             0
# WS50M_RANGE           0
# score          20435100
# dtype: int64

# %% [markdown]
# #### Removing missing values

# %%
# Removing the null values in the target variable as the drought score is only available for once in 7 days.
drought_df = drought_df.dropna()
drought_df.isnull().sum()
# Out:
# fips           0
# date           0
# PRECTOT        0
# PS             0
# QV2M           0
# T2M            0
# T2MDEW         0
# T2MWET         0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# TS             0
# WS10M          0
# WS10M_MAX      0
# WS10M_MIN      0
# WS10M_RANGE    0
# WS50M          0
# WS50M_MAX      0
# WS50M_MIN      0
# WS50M_RANGE    0
# score          0
# dtype: int64

# %% [markdown]
# #### Format Data

# %%
drought_df.dtypes
# Out:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score          float64
# dtype: object

# %%
drought_df['year'] = pd.DatetimeIndex(drought_df['date']).year
drought_df['month'] = pd.DatetimeIndex(drought_df['date']).month 
drought_df['day'] = pd.DatetimeIndex(drought_df['date']).day
drought_df['score'] = drought_df['score'].round().astype(int)
drought_df.dtypes
# Out:
# fips             int64
# date            object
# PRECTOT        float64
# PS             float64
# QV2M           float64
# T2M            float64
# T2MDEW         float64
# T2MWET         float64
# T2M_MAX        float64
# T2M_MIN        float64
# T2M_RANGE      float64
# TS             float64
# WS10M          float64
# WS10M_MAX      float64
# WS10M_MIN      float64
# WS10M_RANGE    float64
# WS50M          float64
# WS50M_MAX      float64
# WS50M_MIN      float64
# WS50M_RANGE    float64
# score            int32
# year             int64
# month            int64
# day              int64
# dtype: object

# %%
drought_df['fips'].nunique()
# Out:
# 3108

# %%
drought_df['score'].round().value_counts()
# Out:
# 0    2093262
# 1     579722
# 2     352327
# 3     221470
# 4     115419
# 5      41060
# Name: score, dtype: int64

# %% [markdown]
# ## EDA

# %%
drought_df.columns
# Out:
# Index(['fips', 'date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
#        'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
#        'WS50M_RANGE', 'score', 'year', 'month', 'day'],
#       dtype='object')

# %% [markdown]
# #### Distribution of continuous variables

# %%
measures = ['PRECTOT','PS','QV2M','T2M','T2MDEW','T2MWET','T2M_MAX','T2M_MIN','T2M_RANGE','TS','WS10M','WS10M_MAX','WS10M_MIN','WS10M_RANGE','WS50M','WS50M_MAX','WS50M_MIN','WS50M_RANGE']
drought_df_measures = drought_df[measures]

# %%
# Calculate number of rows and columns needed
n_measures = len(measures)
n_cols = 4  # Number of columns
n_rows = (n_measures + n_cols - 1) // n_cols  # Calculate number of rows needed

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15))
axes = axes.flatten()  # Flatten to easily iterate over

# Plot histograms 
for ax, col_name in zip(axes, measures):
    ax.hist(drought_df_measures[col_name], bins=30, density=True)  
    ax.set_xlabel(col_name)
    ax.set_ylabel('Density')
    ax.set_title(f'Distribution of {col_name}')

# Remove any empty subplots
for i in range(len(measures), len(axes)):
    fig.delaxes(axes[i])

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Identifying outliers

# %%
plt.figure(figsize=(10,40))
for x in (range(1,19)):
    plt.subplot(19,1,x)
    sns.boxplot(x =  drought_df_measures.columns[x-1], data=drought_df_measures)
    x_name = drought_df_measures.columns[x-1]
    plt.title(f'Distribution of {x_name}')         
plt.tight_layout()

# %%
# Three Standard Deviations Rule (3-sigma Rule)
# Any data point greater than 𝜇+3𝜎 or less than μ−3σ is considered an outlier

print('Total rows = ', len(drought_df_measures.index))
print("{:<70} {:>10}".format('\nColumn Name', 'Outliers'))  # Print header

for i in drought_df_measures.select_dtypes(exclude=['object']).columns:
    num = len(drought_df_measures[
        (drought_df_measures[i] > drought_df_measures[i].mean() + 3 * drought_df_measures[i].std()) | 
        (drought_df_measures[i] < drought_df_measures[i].mean() - 3 * drought_df_measures[i].std())
    ])
    print("{:<70} {:>10}".format(f'Number of values beyond the standard outlier limit in {i} is:', num))
# Out:
# Total rows =  3403260
#
# Column Name                                                             Outliers
# Number of values beyond the standard outlier limit in PRECTOT is:           80854
# Number of values beyond the standard outlier limit in PS is:                90414
# Number of values beyond the standard outlier limit in QV2M is:                  0
# Number of values beyond the standard outlier limit in T2M is:                5649
# Number of values beyond the standard outlier limit in T2MDEW is:             2589
# Number of values beyond the standard outlier limit in T2MWET is:             2164
# Number of values beyond the standard outlier limit in T2M_MAX is:            4381
# Number of values beyond the standard outlier limit in T2M_MIN is:            8148
# Number of values beyond the standard outlier limit in T2M_RANGE is:          4496
# Number of values beyond the standard outlier limit in TS is:                 5921
# Number of values beyond the standard outlier limit in WS10M is:             36093
# Number of values beyond the standard outlier limit in WS10M_MAX is:         29633
# Number of values beyond the standard outlier limit in WS10M_MIN is:         48557
# Number of values beyond the standard outlier limit in WS10M_RANGE is:       44930
# Number of values beyond the standard outlier limit in WS50M is:             28163
# Number of values beyond the standard outlier limit in WS50M_MAX is:         32659
# Number of values beyond the standard outlier limit in WS50M_MIN is:         24247
# Number of values beyond the standard outlier limit in WS50M_RANGE is:       42423

# %%
# Function to filter outliers based on the 3-sigma rule
def remove_outliers(df, columns):
    for col in columns:
        mean = df[col].mean()
        std = df[col].std()
        upper_limit = mean + 3 * std
        lower_limit = mean - 3 * std
        df = df[(df[col] <= upper_limit) & (df[col] >= lower_limit)]
    return df

# Remove outliers
cleaned_drought_df_measures = remove_outliers(drought_df_measures, measures)

# Print the number of rows before and after removing outliers
print(f'Total rows before removing outliers: {len(drought_df_measures)}')
print(f'Total rows after removing outliers: {len(cleaned_drought_df_measures)}')
print(f'Number of outliers: {len(drought_df_measures)-len(cleaned_drought_df_measures)}')
# Out:
# Total rows before removing outliers: 3403260
# Total rows after removing outliers: 3054658
# Number of outliers: 348602

# %% [markdown]
# #### Distribution of categorical variables

# %%
categorical = ['score','year','month','day']
drought_categorical = drought_df[categorical]

# %%
# Calculate number of rows and columns needed
n_measures = len(categorical)
n_cols = 2  # Number of columns
n_rows = 2

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15))
axes = axes.flatten()  # Flatten to easily iterate over

# Plot bar charts
for ax, col_name in zip(axes, categorical):
    ax.bar(drought_categorical[col_name].value_counts().index, drought_categorical[col_name].value_counts().values)  
    ax.set_xlabel(col_name)
    ax.set_ylabel('Count')
    ax.set_title(f'Distribution of {col_name}')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Correlation

# %%
correlati_plot = drought_df_measures.corr()
correlati_plot.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_332af_row0_col0, #T_332af_row1_col1, #T_332af_row2_col2, #T_332af_row3_col3, #T_332af_row3_col9, #T_332af_row4_col4, #T_332af_row4_col5, #T_332af_row5_col4, #T_332af_row5_col5, #T_332af_row6_col6, #T_332af_row7_col7, #T_332af_row8_col8, #T_332af_row9_col3, #T_332af_row9_col9, #T_332af_row10_col10, #T_332af_row11_col11, #T_332af_row12_col12, #T_332af_row13_col13, #T_332af_row14_col14, #T_332af_row15_col15, #T_332af_row16_col16, #T_332af_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_332af_row0_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_332af_row0_col2, #T_332af_row9_col8, #T_332af_row12_col13, #T_332af_row16_col13 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_332af_row0_col3, #T_332af_row0_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_332af_row0_col4, #T_332af_row0_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_332af_row0_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_332af_row0_col7, #T_332af_row1_col9 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_332af_row0_col8, #T_332af_row2_col14, #T_332af_row2_col15, #T_332af_row2_col17, #T_332af_row4_col10, #T_332af_row4_col11, #T_332af_row4_col13, #T_332af_row4_col14, #T_332af_row5_col10, #T_332af_row5_col11, #T_332af_row5_col13, #T_332af_row5_col14, #T_332af_row6_col12, #T_332af_row6_col16, #T_332af_row8_col0, #T_332af_row8_col1, #T_332af_row10_col6, #T_332af_row11_col3, #T_332af_row11_col6, #T_332af_row11_col7, #T_332af_row11_col9, #T_332af_row13_col2, #T_332af_row13_col4, #T_332af_row13_col5, #T_332af_row15_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_332af_row0_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_332af_row0_col10, #T_332af_row8_col7, #T_332af_row8_col13 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_332af_row0_col12, #T_332af_row16_col4, #T_332af_row16_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_332af_row0_col13, #T_332af_row10_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_332af_row0_col14, #T_332af_row8_col15 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_332af_row0_col15, #T_332af_row17_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_332af_row0_col16, #T_332af_row2_col8, #T_332af_row10_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_332af_row0_col17 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_332af_row1_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_332af_row1_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_332af_row1_col3, #T_332af_row3_col1, #T_332af_row9_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_332af_row1_col4, #T_332af_row1_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_332af_row1_col6, #T_332af_row6_col1, #T_332af_row11_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_332af_row1_col7, #T_332af_row17_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_332af_row1_col8, #T_332af_row3_col13, #T_332af_row14_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_332af_row1_col10, #T_332af_row1_col15, #T_332af_row8_col10, #T_332af_row16_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_332af_row1_col11 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_332af_row1_col12, #T_332af_row8_col2, #T_332af_row14_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_332af_row1_col13, #T_332af_row3_col17 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_332af_row1_col14, #T_332af_row8_col14, #T_332af_row12_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_332af_row1_col16 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_332af_row1_col17, #T_332af_row11_col1, #T_332af_row16_col9, #T_332af_row17_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_332af_row2_col0, #T_332af_row2_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_332af_row2_col3, #T_332af_row11_col13, #T_332af_row13_col11 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_332af_row2_col4, #T_332af_row4_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_332af_row2_col5, #T_332af_row5_col2, #T_332af_row10_col14 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_332af_row2_col6 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_332af_row2_col7, #T_332af_row4_col9, #T_332af_row5_col9 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_332af_row2_col9, #T_332af_row6_col4, #T_332af_row6_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_332af_row2_col10, #T_332af_row2_col11, #T_332af_row3_col14, #T_332af_row6_col14, #T_332af_row10_col3, #T_332af_row10_col9, #T_332af_row13_col9, #T_332af_row15_col2, #T_332af_row15_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_332af_row2_col12, #T_332af_row7_col16, #T_332af_row10_col2, #T_332af_row10_col4, #T_332af_row10_col5, #T_332af_row13_col1, #T_332af_row17_col4, #T_332af_row17_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_332af_row2_col13, #T_332af_row4_col15, #T_332af_row4_col17, #T_332af_row5_col15, #T_332af_row5_col17, #T_332af_row7_col14, #T_332af_row11_col2, #T_332af_row11_col4, #T_332af_row11_col5, #T_332af_row13_col7, #T_332af_row15_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_332af_row2_col16, #T_332af_row4_col16, #T_332af_row5_col16, #T_332af_row6_col15, #T_332af_row9_col15, #T_332af_row14_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_332af_row3_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_332af_row3_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_332af_row3_col4, #T_332af_row3_col5, #T_332af_row14_col15, #T_332af_row15_col14 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_332af_row3_col6, #T_332af_row3_col7, #T_332af_row6_col3, #T_332af_row7_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_332af_row3_col8, #T_332af_row4_col0, #T_332af_row5_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_332af_row3_col10, #T_332af_row7_col10, #T_332af_row7_col12, #T_332af_row9_col12, #T_332af_row9_col16, #T_332af_row15_col4, #T_332af_row17_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_332af_row3_col11, #T_332af_row6_col11, #T_332af_row7_col17, #T_332af_row8_col12, #T_332af_row9_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_332af_row3_col12, #T_332af_row8_col16, #T_332af_row13_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_332af_row3_col15, #T_332af_row7_col11 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_332af_row3_col16, #T_332af_row6_col10, #T_332af_row7_col15, #T_332af_row10_col7, #T_332af_row14_col6, #T_332af_row14_col9, #T_332af_row15_col6, #T_332af_row17_col2, #T_332af_row17_col16 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_332af_row4_col1, #T_332af_row5_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_332af_row4_col3, #T_332af_row5_col3, #T_332af_row14_col11 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_332af_row4_col6, #T_332af_row5_col6 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_332af_row4_col7, #T_332af_row5_col7, #T_332af_row6_col7, #T_332af_row7_col6, #T_332af_row12_col16, #T_332af_row16_col12 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_332af_row4_col8, #T_332af_row5_col8, #T_332af_row16_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_332af_row4_col12, #T_332af_row5_col12, #T_332af_row9_col14, #T_332af_row13_col6, #T_332af_row14_col3, #T_332af_row14_col7, #T_332af_row15_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_332af_row6_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_332af_row6_col2, #T_332af_row13_col15 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_332af_row6_col8, #T_332af_row10_col17 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_332af_row6_col9, #T_332af_row7_col9, #T_332af_row9_col6, #T_332af_row9_col7 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_332af_row6_col13, #T_332af_row17_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_332af_row6_col17, #T_332af_row17_col12 {
#   b

# %% [markdown]
# Attributes QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN and TS have shown strong positive correlation
# Similary WS10M, WS10M_MAX and WS10M_MIN have shown a strong positve correlation
# Likewise, WS50M, WS50M_MAX and WS50M_MIN show strong positive correlation
# However, from the scatter plots above, we see significant variance between the data points, despite the strong positive correlation. Hence we'll retain all these variables, and try other feature selection methods.

# %% [markdown]
# ## Data Eng

# %%
# X_train = drought_df_train.drop(['fips', 'date', 'score'], axis=1)
# y_train = drought_df_train['score']

# X_test = drought_df_test.drop(['fips', 'date', 'score'], axis=1)
# y_test = drought_df_test['score']


X_train, X_test, y_train, y_test = train_test_split(drought_df_measures, drought_df['score'], test_size=0.2, random_state=42)

# %%
print("Train features shape", X_train.shape)
print("Train target shape", y_train.shape)
print("Test features shape", X_test.shape)
print("Test target shape", y_test.shape)
# Out:
# Train features shape (2722608, 18)
# Train target shape (2722608,)
# Test features shape (680652, 18)
# Test target shape (680652,)

# %% [markdown]
# #### Standardizing the data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Feature Selection

# %%
# Recursive Feature Elimination (RFE) with Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rfe = RFE(estimator=rf, n_features_to_select=10, step=1)
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))
selected_features = X_train.columns[(fit.get_support())]
print(selected_features)
